# %%
from datasets import load_dataset

# %%
dataset = load_dataset("open_subtitles", lang1="en", lang2="sk")
# Out:
# Using custom data configuration en-sk-lang1=en,lang2=sk
# Reusing dataset open_subtitles (C:\Users\marek\.cache\huggingface\datasets\open_subtitles\en-sk-lang1=en,lang2=sk\0.0.0\c1ec973ca4b6e588740d8f167cc0e24ea3f626e70bc7ffe467e944730500e198)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'meta', 'translation'],
#         num_rows: 8850871
#     })
# })

# %%
dataset.keys()
# Out:
# dict_keys(['train'])

# %%
def check_split(dataset):
    keys = dataset.keys()

    lenght = len(keys)

    sets = {}
    for i in ['train', 'validation', 'test']:
        if i in keys:
            sets[i] = dataset[i]

    if 'train' in keys and 'test' not in keys:
        if 'train' in keys:
            new = dataset['train'].train_test_split(test_size=0.2, seed=1)
            sets['train'] = new['train']
            sets['test'] = new['test']
    
    if 'train' not in keys:
        raise RuntimeError("Dataset does not have 'train' split")

    return sets.values()

# %%
check_split(dataset)
# Out:
# Loading cached split indices for dataset at C:\Users\marek\.cache\huggingface\datasets\open_subtitles\en-sk-lang1=en,lang2=sk\0.0.0\c1ec973ca4b6e588740d8f167cc0e24ea3f626e70bc7ffe467e944730500e198\cache-4e7fe51fbd9974eb.arrow and C:\Users\marek\.cache\huggingface\datasets\open_subtitles\en-sk-lang1=en,lang2=sk\0.0.0\c1ec973ca4b6e588740d8f167cc0e24ea3f626e70bc7ffe467e944730500e198\cache-75b782b879e50ad9.arrow
# dict_values([Dataset({
#     features: ['id', 'meta', 'translation'],
#     num_rows: 7080696
# }), Dataset({
#     features: ['id', 'meta', 'translation'],
#     num_rows: 1770175
# })])

# %%
dataset = load_dataset("glue", "cola")
# Out:
# Reusing dataset glue (C:\Users\marek\.cache\huggingface\datasets\glue\cola\1.0.0\dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad)
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['sentence', 'label', 'idx'],
#         num_rows: 8551
#     })
#     validation: Dataset({
#         features: ['sentence', 'label', 'idx'],
#         num_rows: 1043
#     })
#     test: Dataset({
#         features: ['sentence', 'label', 'idx'],
#         num_rows: 1063
#     })
# })

# %%
check_split(dataset)
# Out:
# dict_values([Dataset({
#     features: ['sentence', 'label', 'idx'],
#     num_rows: 8551
# }), Dataset({
#     features: ['sentence', 'label', 'idx'],
#     num_rows: 1043
# }), Dataset({
#     features: ['sentence', 'label', 'idx'],
#     num_rows: 1063
# })])

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
  
tokenizer = AutoTokenizer.from_pretrained("Helsinki-NLP/opus-mt-en-sk")

model = AutoModelForSeq2SeqLM.from_pretrained("Helsinki-NLP/opus-mt-en-sk")

# %%
model.config
# Out:
# MarianConfig {
#   "_name_or_path": "Helsinki-NLP/opus-mt-en-sk",
#   "_num_labels": 3,
#   "activation_dropout": 0.0,
#   "activation_function": "swish",
#   "add_bias_logits": false,
#   "add_final_layer_norm": false,
#   "architectures": [
#     "MarianMTModel"
#   ],
#   "attention_dropout": 0.0,
#   "bad_words_ids": [
#     [
#       60024
#     ]
#   ],
#   "bos_token_id": 0,
#   "classif_dropout": 0.0,
#   "classifier_dropout": 0.0,
#   "d_model": 512,
#   "decoder_attention_heads": 8,
#   "decoder_ffn_dim": 2048,
#   "decoder_layerdrop": 0.0,
#   "decoder_layers": 6,
#   "decoder_start_token_id": 60024,
#   "dropout": 0.1,
#   "encoder_attention_heads": 8,
#   "encoder_ffn_dim": 2048,
#   "encoder_layerdrop": 0.0,
#   "encoder_layers": 6,
#   "eos_token_id": 0,
#   "forced_eos_token_id": 0,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "init_std": 0.02,
#   "is_encoder_decoder": true,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "max_length": 512,
#   "max_position_embeddings": 512,
#   "model_type": "marian",
#   "normalize_before": false,
#   "normalize_embedding": false,
#   "num_beams": 4,
#   "num_hidden_layers": 6,
#   "pad_token_id": 60024,
#   "scale_embedding": true,
#   "static_position_embeddings": true,
#   "transformers_version": "4.11.3",
#   "use_cache": true,
#   "vocab_size": 60025
# }

# %%
tokenizer
# Out:
# PreTrainedTokenizer(name_or_path='Helsinki-NLP/opus-mt-en-sk', vocab_size=60025, model_max_len=512, is_fast=False, padding_side='right', special_tokens={'eos_token': '</s>', 'unk_token': '<unk>', 'pad_token': '<pad>'})

# %%
model.config.to_dict()
# Out:
# {'vocab_size': 60025,
#  'max_position_embeddings': 512,
#  'd_model': 512,
#  'encoder_ffn_dim': 2048,
#  'encoder_layers': 6,
#  'encoder_attention_heads': 8,
#  'decoder_ffn_dim': 2048,
#  'decoder_layers': 6,
#  'decoder_attention_heads': 8,
#  'dropout': 0.1,
#  'attention_dropout': 0.0,
#  'activation_dropout': 0.0,
#  'activation_function': 'swish',
#  'init_std': 0.02,
#  'encoder_layerdrop': 0.0,
#  'decoder_layerdrop': 0.0,
#  'classifier_dropout': 0.0,
#  'use_cache': True,
#  'num_hidden_layers': 6,
#  'scale_embedding': True,
#  'return_dict': True,
#  'output_hidden_states': False,
#  'output_attentions': False,
#  'torchscript': False,
#  'torch_dtype': None,
#  'use_bfloat16': False,
#  'pruned_heads': {},
#  'tie_word_embeddings': True,
#  'is_encoder_decoder': True,
#  'is_decoder': False,
#  'add_cross_attention': False,
#  'tie_encoder_decoder': False,
#  'max_length': 512,
#  'min_length': 0,
#  'do_sample': False,
#  'early_stopping': False,
#  'num_beams': 4,
#  'num_beam_groups': 1,
#  'diversity_penalty': 0.0,
#  'temperature': 1.0,
#  'top_k': 50,
#  'top_p': 1.0,
#  'repetition_penalty': 1.0,
#  'length_penalty': 1.0,
#  'no_repeat_ngram_size': 0,
#  'encoder_no_repeat_ngram_size': 0,
#  'bad_words_ids': [[60024]],
#  'num_return_sequences': 1,
#  'chunk_size_feed_forward': 0,
#  'output_scores': False,
#  'return_dict_in_generate': False,
#  'forced_bos_token_id': None,
#  'forced_eos_token_id': 0,
#  'remove_invalid_values': False,
#  'architectures': ['MarianMTModel'],
#  'finetuning_task': None,
#  'id2label': {0: 'LABEL_0', 1: 'LABEL_1', 2: 'LABEL_2'},
#  'label2id': {'LABEL_0': 0, 'LABEL_1': 1, 'LABEL_2': 2},
#  'tokenizer_class': None,
#  'prefix': None,
#  'bos_token_id': 0,
#  'pad_token_id': 60024,
#  'eos_token_id': 0,
#  'sep_token_id': None,
#  'decoder_start_token_id': 60024,
#  'task_specific_params': None,
#  'problem_type': None,
#  '_name_or_path': 'Helsinki-NLP/opus-mt-en-sk',
#  'transformers_version': '4.11.3',
#  '_num_labels': 3,
#  'add_bias_logits': False,
#  'add_final_layer_norm': False,
#  'classif_dropout': 0.0,
#  'model_type': 'marian',
#  'normalize_before': False,
#  'normalize_embedding': False,
#  'static_position_embeddings': True}

# %%
from datasets import load_dataset
dataset = load_dataset("open_subtitles",lang1="en",lang2="sk")
# Out:
# Using custom data configuration en-sk-lang1=en,lang2=sk
# Reusing dataset open_subtitles (C:\Users\marek\.cache\huggingface\datasets\open_subtitles\en-sk-lang1=en,lang2=sk\0.0.0\c1ec973ca4b6e588740d8f167cc0e24ea3f626e70bc7ffe467e944730500e198)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'meta', 'translation'],
#         num_rows: 8850871
#     })
# })

# %%
dataset['train'][0]
# Out:
# {'translation': {'en': 'Subtitles by DramaFever',
#   'sk': 'Subtitles by DramaFever'},
#  'id': '0',
#  'meta': {'year': 0,
#   'imdbId': 3245996,
#   'subtitleId': {'en': 5698460, 'sk': 5232687},
#   'sentenceIds': {'en': [1], 'sk': [1]}}}

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'meta', 'translation'],
#         num_rows: 8850871
#     })
# })

# %%
dataset['train'].info
# Out:
# DatasetInfo(description='This is a new collection of translated movie subtitles from http://www.opensubtitles.org/.\n\nIMPORTANT: If you use the OpenSubtitle corpus: Please, add a link to http://www.opensubtitles.org/ to your website and to your reports and publications produced with the data!\n\nThis is a slightly cleaner version of the subtitle collection using improved sentence alignment and better language checking.\n\n62 languages, 1,782 bitexts\ntotal number of files: 3,735,070\ntotal number of tokens: 22.10G\ntotal number of sentence fragments: 3.35G\n', citation='P. Lison and J. Tiedemann, 2016, OpenSubtitles2016: Extracting Large Parallel Corpora from Movie and TV Subtitles. In Proceedings of the 10th International Conference on Language Resources and Evaluation (LREC 2016)\n', homepage='http://opus.nlpl.eu/OpenSubtitles.php', license='', features={'id': Value(dtype='string', id=None), 'meta': {'year': Value(dtype='uint32', id=None), 'imdbId': Value(dtype='uint32', id=None), 'subtitleId': {'en': Value(dtype='uint32', id=None), 'sk': Value(dtype='uint32', id=None)}, 'sentenceIds': {'en': Sequence(feature=Value(dtype='uint32', id=None), length=-1, id=None), 'sk': Sequence(feature=Value(dtype='uint32', id=None), length=-1, id=None)}}, 'translation': Translation(languages=['en', 'sk'], id=None)}, post_processed=None, supervised_keys=None, task_templates=None, builder_name='open_subtitles', config_name='en-sk', version=0.0.0, splits={'train': SplitInfo(name='train', num_bytes=1016752986, num_examples=8850871, dataset_name='open_subtitles')}, download_checksums={'https://object.pouta.csc.fi/OPUS-OpenSubtitles/v2018/moses/en-sk.txt.zip': {'num_bytes': 270900547, 'checksum': '4e42ea3959a8285b5043495fa072362ff8d3dd3fb0646723dcb4f1868a29343f'}}, download_size=270900547, post_processing_size=None, dataset_size=1016752986, size_in_bytes=1287653533)

# %%
def f(a):
    print(a)
    pass

# %%
dataset.map(f)
# Out:
#   0%|          | 0/8850871 [00:00<?, ?ex/s]
# {'id': '0', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [1], 'sk': [1]}}, 'translation': {'en': 'Subtitles by DramaFever', 'sk': 'Subtitles by DramaFever'}}
# {'id': '1', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [2], 'sk': [2]}}, 'translation': {'en': 'Episode 2.', 'sk': 'Epizóda 2'}}
# {'id': '2', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [3], 'sk': [3]}}, 'translation': {'en': 'Who are you?', 'sk': 'Kto ste?'}}
# {'id': '3', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [4], 'sk': [4]}}, 'translation': {'en': '- I really just want to sleep.', 'sk': '- Naozaj chcem len spať.'}}
# {'id': '4', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [5], 'sk': [5]}}, 'translation': {'en': '- Wake up and open your eyes!', 'sk': '- Prebuďte sa a otvorte oči!'}}
# {'id': '5', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [6], 'sk': [6]}}, 'translation': {'en': '- Please just sleep with me.', 'sk': '- Poďme spolu spať.'}}
# {'id': '6', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [7], 'sk': [7]}}, 'translation': {'en': '- What?', 'sk': '- Čože?'}}
# {'id': '7', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [8], 'sk': [8]}}, 'translation': {'en': 'Are you asking me to sleep with you?', 'sk': 'Chcete po mne, aby som s vami spal?'}}
# {'id': '8', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [9], 'sk': [9]}}, 'translation': {'en': "With... the way you look right now... you're standing there asking me to sleep with you?", 'sk': 'V tomto stave, hovoríte, že chcete so mnou spať?'}}
# {'id': '9', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [10], 'sk': [10]}}, 'translation': {'en': "Let's sleep.", 'sk': 'Poďme spať.'}}
# {'id': '10', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [11], 'sk': [11]}}, 'translation': {'en': 'I can sleep with you.', 'sk': 'Chcem s vami spať.'}}
# {'id': '11', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [12], 'sk': [12]}}, 'translation': {'en': "I can't sleep with you.", 'sk': 'Nemôžem s vami spať.'}}
# {'id': '12', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [13], 'sk': [13]}}, 'translation': {'en': 'Stop dreaming.', 'sk': 'Prestaňte snívať.'}}
# {'id': '13', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [14], 'sk': [14]}}, 'translation': {'en': 'You.', 'sk': 'Vy.'}}
# {'id': '14', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [15], 'sk': [15]}}, 'translation': {'en': "Just because you keep touching me, and asking me to sleep with you... you think... that I'll fall for you?", 'sk': 'Len preto, že sa ma stále dotýkate, a žiadate ma, aby som s vami spal, myslíte si, že sa do vás zamilujem?'}}
# {'id': '15', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [16], 'sk': [16]}}, 'translation': {'en': 'When did you last wash your hair?', 'sk': 'Kedy ste si naposledy umyla vlasy?'}}
# {'id': '16', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [17], 'sk': [17]}}, 'translation': {'en': "If you're going to try to seduce someone, try washing your hair first!", 'sk': 'Ak chcete niekoho zviesť, najprv si umyte vlasy!'}}
# {'id': '17', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [18], 'sk': [18]}}, 'translation': {'en': "It's not like you're even going to sleep with me.", 'sk': 'Nemala som na mysli milovanie.'}}
# {'id': '18', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [19], 'sk': [19]}}, 'translation': {'en': 'Why did you come here?', 'sk': 'Prečo ste tu?'}}
# {'id': '19', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [20], 'sk': [20]}}, 'translation': {'en': 'I heard... that you were going around talking about me?', 'sk': 'Počul som, že ste hovorila o mojej minulosti.'}}
# {'id': '20', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [21], 'sk': [21]}}, 'translation': {'en': 'What is it that you heard about me?', 'sk': 'Čo ste o mne počula?'}}
# {'id': '21', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [22], 'sk': [22]}}, 'translation': {'en': 'Or do you really... know something about her?', 'sk': 'Naozaj o nej... niečo viete?'}}
# {'id': '22', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [23], 'sk': [23]}}, 'translation': {'en': 'Did you... and Hee Joo know each other?', 'sk': 'Naozaj... poznáte Hee Joo?'}}
# {'id': '23', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [24], 'sk': [24]}}, 'translation': {'en': "That woman's name was Hee Joo?", 'sk': 'Tá žena sa volá Hee Joo?'}}
# {'id': '24', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [25], 'sk': [25]}}, 'translation': {'en': 'What is this?', 'sk': 'Čo to má byť?'}}
# {'id': '25', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [26], 'sk': [26]}}, 'translation': {'en': 'How do you know Hee Joo?', 'sk': 'Ako to, že poznáte Hee Joo?'}}
# {'id': '26', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [27], 'sk': [27]}}, 'translation': {'en': 'I saw her.', 'sk': 'Videla som ju.'}}
# {'id': '27', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [28], 'sk': [28]}}, 'translation': {'en': 'That woman...', 'sk': 'Tú ženu...'}}
# {'id': '28', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [29], 'sk': [29]}}, 'translation': {'en': 'I saw her.', 'sk': 'Videla som ju.'}}
# {'id': '29', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [30], 'sk': [30]}}, 'translation': {'en': 'What?', 'sk': 'Čože?'}}
# {'id': '30', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [31], 'sk': [31]}}, 'translation': {'en': 'Are you still not fully awake?', 'sk': 'Ešte stále nie ste pri vedomí?'}}
# {'id': '31', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [32], 'sk': [32]}}, 'translation': {'en': '- That woman...', 'sk': '- Tá žena ...'}}
# {'id': '32', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [33], 'sk': [33]}}, 'translation': {'en': "- She's dead, right?", 'sk': '- Je mŕtva, však?'}}
# {'id': '33', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [34], 'sk': [34]}}, 'translation': {'en': "That's right.", 'sk': 'Presne tak.'}}
# {'id': '34', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [35], 'sk': [35]}}, 'translation': {'en': 'Hee Joo died a long time ago.', 'sk': 'Hee Joo zomrela už dávno.'}}
# {'id': '35', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [36], 'sk': [36]}}, 'translation': {'en': 'So when and how are you saying that you saw her?', 'sk': 'Takže, kedy ste ju videla?'}}
# {'id': '36', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [37], 'sk': [37]}}, 'translation': {'en': 'I saw... that woman standing next to you recently.', 'sk': 'Videla som... posledne tú ženu stáť vedľa vás.'}}
# {'id': '37', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [38], 'sk': [38]}}, 'translation': {'en': 'I... see dead people.', 'sk': 'Ja... vidím mŕtvych ľudí.'}}
# {'id': '38', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [39], 'sk': [39]}}, 'translation': {'en': "The master's woman is a ghost.", 'sk': 'Śéfova žena je duch.'}}
# {'id': '39', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [40], 'sk': [40]}}, 'translation': {'en': "It's a pretty famous story at Kingdom Enterprises.", 'sk': 'Je to dosť známy príbeh v Kingdom Enterprises.'}}
# {'id': '40', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [41], 'sk': [41]}}, 'translation': {'en': 'Our President Joo is still living with the memories of his dead first love in his heart.', 'sk': 'Náš prezident Joo stále žije so spomienkami vo svojom srdci, na svoju mŕtvu prvú lásku.'}}
# {'id': '41', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [42], 'sk': [42]}}, 'translation': {'en': "That's why he's still not even married.", 'sk': 'Preto ešte stále nie je ženatý.'}}
# {'id': '42', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [43], 'sk': [43]}}, 'translation': {'en': "Whenever he even thinks about getting married the dead woman's ghost appears, and breaks up the relationship, right?", 'sk': 'Vždy, keď pomýšľa na svadbu, mŕtvy duch ženy sa zjaví a vzťah rozbije, však?'}}
# {'id': '43', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [44], 'sk': [44]}}, 'translation': {'en': 'A dead woman?', 'sk': 'Mŕtva žena?'}}
# {'id': '44', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [45], 'sk': [45]}}, 'translation': {'en': 'Are you talking about the female student that died in the car accident that was related to President Joo a long time ago?', 'sk': 'Hovoríš o tom, že tá študentka, ktorá zomrela pri dopravnej nehode, súvisí s prezidentom Joo?'}}
# {'id': '45', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [46], 'sk': [46]}}, 'translation': {'en': "That's right!", 'sk': 'Presne tak!'}}
# {'id': '46', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [47], 'sk': [47]}}, 'translation': {'en': 'That was a pretty well-known accident.', 'sk': 'To bola celkom známa nehoda.'}}
# {'id': '47', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [48], 'sk': [48]}}, 'translation': {'en': 'I remember it being all over the news when I was younger.', 'sk': 'Keď som bol mladší spomínam si, že to bolo vo všetkých správach.'}}
# {'id': '48', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [49], 'sk': [49]}}, 'translation': {'en': 'The rich boy and his girlfriend both were kidnapped together.', 'sk': 'Uniesli bohatého chlapca a jeho priateľku.'}}
# {'id': '49', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [50], 'sk': [50]}}, 'translation': {'en': "It was the 'Ten billion won kidnapping' case.", 'sk': 'Bol to prípad únosu za 10 miliárd dolárov.'}}
# {'id': '50', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [51], 'sk': [51]}}, 'translation': {'en': 'They lost the ransom money, but never caught the culprits, right?', 'sk': 'Prišli o peniaze za výkupné, ale vinníkov nikdy nechytili, však?'}}
# {'id': '51', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [52, 53], 'sk': [52]}}, 'translation': {'en': 'Ten billion back then would be about... equivalent to 100 billion won now?', 'sk': 'Desať miliár by vtedy zodpovedalo dnešným 100 biliónom wonov?'}}
# {'id': '52', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [54], 'sk': [53]}}, 'translation': {'en': '- 100 billion won?', 'sk': '- 100 biliónov wonov?'}}
# {'id': '53', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [55], 'sk': [54]}}, 'translation': {'en': '- Billions!', 'sk': '- Bilióny!'}}
# {'id': '54', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [56, 57], 'sk': [55]}}, 'translation': {'en': "I'm sure the guys who took that money... are living very well somewhere.", 'sk': 'Som si istý, že chlapci, ktorí tie peniaze vzali, si niekde veľmi dobre žijú.'}}
# {'id': '55', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [58], 'sk': [56]}}, 'translation': {'en': 'But...', 'sk': 'Ale...'}}
# {'id': '56', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [59], 'sk': [57]}}, 'translation': {'en': "Do all the employees call President Joo, 'The Master'?", 'sk': "Všetci zamestnanci volajú prezidenta Joo, 'Pán'?"}}
# {'id': '57', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [60], 'sk': [58]}}, 'translation': {'en': 'Joo Joong Won is the king of Kingdom Enterprises.', 'sk': 'Joo Joong Won je kráľ Kingdom Enterprises.'}}
# {'id': '58', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [61], 'sk': [59]}}, 'translation': {'en': "That's why he's called 'The Master'.", 'sk': "Preto ho volajú 'Pán'."}}
# {'id': '59', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [62], 'sk': [60]}}, 'translation': {'en': "He also known as 'The Tyrant'.", 'sk': "Známy je aj ako 'Tyran'."}}
# {'id': '60', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [63], 'sk': [61]}}, 'translation': {'en': 'The master is living well while acting like a tyrant.', 'sk': 'Šéf si žije dobre a pritom sa chová ako tyran.'}}
# {'id': '61', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [64], 'sk': [62]}}, 'translation': {'en': "So, it's understandable that the unfortunate girl who was kidnapped along with him would become a restless ghost from the injustice of her death.", 'sk': 'Takže je pochopiteľné, že nešťastná dievčina, ktorú uniesli... spolu s ním, sa stala nepokojným duchom, kvôli jej nespravodlivej smrti.'}}
# {'id': '62', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [65], 'sk': [63]}}, 'translation': {'en': 'Master...', 'sk': '"Pán"...'}}
# {'id': '63', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [66], 'sk': [64]}}, 'translation': {'en': 'Find me my justice.', 'sk': '"Zisti pravdu".'}}
# {'id': '64', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [67], 'sk': [65]}}, 'translation': {'en': 'The rumor has it that she crys like that while roaming around Kingdom Enterprise.', 'sk': 'Hovorí, sa že takto narieka, keď sa túla po Kingdom Enterprises.'}}
# {'id': '65', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [68], 'sk': [66]}}, 'translation': {'en': "And because of that, I can't even sleep at night.", 'sk': 'A kvôli tomu v noci nemôžem spať.'}}
# {'id': '66', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [69], 'sk': [67]}}, 'translation': {'en': "- Let's toast to that.", 'sk': '- Poďme si na to pripiť.'}}
# {'id': '67', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [70], 'sk': [68]}}, 'translation': {'en': 'Cheers!', 'sk': 'Na zdravie!'}}
# {'id': '68', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [71], 'sk': [69]}}, 'translation': {'en': '- Cheers!', 'sk': '- Na zdravie!'}}
# {'id': '69', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [72], 'sk': [70]}}, 'translation': {'en': 'There was an incident where I almost died, but I somehow came back to life.', 'sk': 'Došlo k nehode, pri ktorej som skoro umrela, ale nejako som sa prebrala k životu.'}}
# {'id': '70', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [73], 'sk': [71]}}, 'translation': {'en': 'Ever since then...', 'sk': 'Od tej doby ...'}}
# {'id': '71', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [74], 'sk': [72]}}, 'translation': {'en': 'I see dead people.', 'sk': 'Vidím mŕtvych ľudí.'}}
# {'id': '72', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [75], 'sk': [73]}}, 'translation': {'en': "So, you're telling me that you saw Hee Joo who died 15 years ago... the day before yesterday?", 'sk': 'Takže mi tvrdíte, že ste predvčerom videla Hee Joo, ktorá zomrela pred 15 rokmi?'}}
# {'id': '73', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [76], 'sk': [74]}}, 'translation': {'en': 'That day... when you got mad at me and left...', 'sk': 'Videla som ju... v ten deň, keď ste sa na mňa naštval a odišiel.'}}
# {'id': '74', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [78], 'sk': [75]}}, 'translation': {'en': "If she's dead, then it's all over.", 'sk': 'Ak je mŕtva, všetkému je koniec.'}}
# {'id': '75', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [79], 'sk': [76]}}, 'translation': {'en': "Stop pestering someone who's still alive.", 'sk': 'Neobťažujte živého človeka.'}}
# {'id': '76', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [80], 'sk': [77]}}, 'translation': {'en': 'Even though it was just for a moment...', 'sk': 'Aj keď to bolo len na chvíľu...'}}
# {'id': '77', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [81], 'sk': [78]}}, 'translation': {'en': 'I still saw her.', 'sk': 'Videla som ju.'}}
# {'id': '78', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [82], 'sk': [79]}}, 'translation': {'en': "You're telling me that you see ghosts?", 'sk': 'Tvrdíte mi, že vidíte duchov?'}}
# {'id': '79', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [83], 'sk': [80]}}, 'translation': {'en': 'Are there any ghosts here with us right now?', 'sk': 'Aj teraz sú tu duchovia?'}}
# {'id': '80', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [84], 'sk': [81]}}, 'translation': {'en': 'How many of them are there?', 'sk': 'Koľko ich je?'}}
# {'id': '81', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [85], 'sk': [82]}}, 'translation': {'en': 'See that chair over there?', 'sk': 'Vidíte tú stoličku?'}}
# {'id': '82', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [86], 'sk': [83]}}, 'translation': {'en': "Do you see how it's rocking back and forth even though the wind isn't even blowing?", 'sk': 'Vidíte, ako sa kýva sem a tam, aj keď nefúka vietor?'}}
# {'id': '83', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [87], 'sk': [84]}}, 'translation': {'en': 'So what?', 'sk': 'No a?'}}
# {'id': '84', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [88], 'sk': [85]}}, 'translation': {'en': "There's one right there.", 'sk': 'Teraz tu jeden je.'}}
# {'id': '85', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [89], 'sk': [86]}}, 'translation': {'en': "You're telling me... that there's one on that chair over there?", 'sk': 'Hovoríte... že je na stoličke?'}}
# {'id': '86', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [90], 'sk': [87]}}, 'translation': {'en': 'Sometimes they come looking for me...', 'sk': 'Niekedy prídu za mnou ...'}}
# {'id': '87', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [91], 'sk': [88]}}, 'translation': {'en': 'or they find me on the streets.', 'sk': 'alebo ma nájdu na uliciach.'}}
# {'id': '88', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [92, 93], 'sk': [89]}}, 'translation': {'en': 'I try my best to ignore them... but they keep... following me around.', 'sk': 'Snažím sa ich ignorovať, ale stále ma prenasledujú.'}}
# {'id': '89', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [94], 'sk': [90]}}, 'translation': {'en': 'Sometimes... they want to talk to me.', 'sk': 'Niekedy ... chcú so mnou hovoriť.'}}
# {'id': '90', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [95], 'sk': [91]}}, 'translation': {'en': 'And sometimes... they ask me for my help.', 'sk': 'A niekedy ... ma žiadajú o pomoc.'}}
# {'id': '91', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [96], 'sk': [92]}}, 'translation': {'en': "They always cling onto me so that I can't even sleep.", 'sk': 'Vždy sa ma pevne držia, takže nemôžem ani spať.'}}
# {'id': '92', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [97], 'sk': [93]}}, 'translation': {'en': "I'm so afraid of them and can't stand having them around.", 'sk': 'Desí ma to a nepáči sa mi to, ale nič s tým nemôžem robiť.'}}
# {'id': '93', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [98], 'sk': [94]}}, 'translation': {'en': "But I can't help myself from seeing and hearing them.", 'sk': 'Nemôžem si pomôcť, stále ich vídím a počujem.'}}
# {'id': '94', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [99], 'sk': [95]}}, 'translation': {'en': "But when I hold onto you like this, I don't see nor hear them anymore.", 'sk': 'Ale keď sa vás chytím, tak zmiznú.'}}
# {'id': '95', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [100], 'sk': [96]}}, 'translation': {'en': "I've never met someone like you.", 'sk': 'Nikdy som nestretla niekoho, ako ste vy.'}}
# {'id': '96', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [101], 'sk': [97]}}, 'translation': {'en': "That's why you're so special to me.", 'sk': 'Preto ste pre mňa taký dôležitý.'}}
# {'id': '97', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [102], 'sk': [98]}}, 'translation': {'en': 'I wonder... what you mean to me?', 'sk': 'Rada by som vedela, čo pre mňa znamenáte?'}}
# {'id': '98', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [103], 'sk': [99]}}, 'translation': {'en': "I have a feeling... that I'll be able to sleep well, and live a normal life if I stay with you.", 'sk': 'Mám pocit, že keď zostanem s vami, budem môcť dobre spať a normálne žiť.'}}
# {'id': '99', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [104], 'sk': [100]}}, 'translation': {'en': 'I want to remain by your side.', 'sk': 'Chcem byť s vami.'}}
# {'id': '100', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [105], 'sk': [101]}}, 'translation': {'en': 'You want to be with me that badly?', 'sk': 'Vážne chcete byť so mnou?'}}
# {'id': '101', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [106], 'sk': [102]}}, 'translation': {'en': "Why don't you just tell me that you own this building?", 'sk': 'Prečo mi jednoducho nepoviete, že vlastníte túto budovu?'}}
# {'id': '102', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [107], 'sk': [103]}}, 'translation': {'en': "Then, I'll look you over since this building is expensive here.", 'sk': 'Tak by som prejavil záujem, pretože pôda je tu drahá.'}}
# {'id': '103', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [108], 'sk': [104]}}, 'translation': {'en': 'I really am so miserable.', 'sk': 'Naozaj sa cítim hrozne.'}}
# {'id': '104', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [109], 'sk': [105]}}, 'translation': {'en': "You may not know what it's like since you can't hear them or see them but I'm so terrified.", 'sk': 'Nemôžete to vedieť, pretože ich nevidíte a nepočujete, ale ja som veľmi vydesená.'}}
# {'id': '105', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [110], 'sk': [106]}}, 'translation': {'en': "I'm not scared of something that I can't see nor hear.", 'sk': 'Nebojím sa niečoho, čo nevidím a nepočujem.'}}
# {'id': '106', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [111], 'sk': [107]}}, 'translation': {'en': "It is you, whom I can see and hear that I'm afraid of.", 'sk': 'Ale koho sa bojím, ste vy.'}}
# {'id': '107', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [112], 'sk': [108]}}, 'translation': {'en': "You're scared of this chair because it keeps on rocking?", 'sk': 'Bojíte sa tohto kresla, pretože sa hojdá?'}}
# {'id': '108', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [113], 'sk': [109]}}, 'translation': {'en': 'What do you think?', 'sk': 'A čo toto?'}}
# {'id': '109', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [114], 'sk': [110]}}, 'translation': {'en': 'Does this scare you even more now?', 'sk': 'Bojíte sa ešte viac?'}}
# {'id': '110', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [115], 'sk': [111]}}, 'translation': {'en': 'You.', 'sk': 'Vy.'}}
# {'id': '111', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [116], 'sk': [112]}}, 'translation': {'en': "If you ever try to make another pass at me, then I'll really destroy you.", 'sk': 'Ak ešte niekedy budete na mňa niečo skúšať, potom vás naozaj zničím.'}}
# {'id': '112', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [117, 118], 'sk': [113]}}, 'translation': {'en': "No matter what kind of scary things that you may do to me I don't think it could be any scarier than what I'm looking at right now.", 'sk': 'Aj keby ste urobil niečo desivejšie, nemyslím si, že to môžete porovnať s tým, čo práve vidím.'}}
# {'id': '113', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [119], 'sk': [114]}}, 'translation': {'en': "I'm just going to run away and stay right next to you.", 'sk': 'Chcem utiecť a zostať s vami.'}}
# {'id': '114', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [120], 'sk': [115]}}, 'translation': {'en': "So, it's not because I have an immense amount of money or because I'm unbelievably good looking.", 'sk': 'Takže, nie preto, že mám obrovské množstvo peňazí, alebo preto, že neuveriteľne dobre vyzerám.'}}
# {'id': '115', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [121], 'sk': [116]}}, 'translation': {'en': "You want to be with me because you're afraid of ghosts?", 'sk': 'Chcete byť so mnou, pretože sa bojíte duchov?'}}
# {'id': '116', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [122], 'sk': [117]}}, 'translation': {'en': "That's a very refreshing approach.", 'sk': 'To je veľmi komický prístup.'}}
# {'id': '117', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [123], 'sk': [118]}}, 'translation': {'en': "It's more like a desperate approach.", 'sk': 'Je to skôr zúfalý prístup.'}}
# {'id': '118', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [124], 'sk': [119]}}, 'translation': {'en': "It's too lonely and sad for me to continue to live on like this.", 'sk': 'Som taká osamelá a smutná.'}}
# {'id': '119', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [125], 'sk': [120]}}, 'translation': {'en': 'Look here, Ms. Tae Gong Shil.', 'sk': 'Pozrite sa, slečna Tae Gong Sil.'}}
# {'id': '120', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [126], 'sk': [121, 122]}}, 'translation': {'en': 'Even when that infamous girl Candy makes a pass on a rich man no matter how lonely or sad she is... she always ties her back hair neatly before she comes onto the man.', 'sk': 'Aj vykričaná Candy, keď šla po boháčoch, aj keby bol osamelá a smutná, vždy si úhľadne zviazala vlasy.'}}
# {'id': '121', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [127], 'sk': [123]}}, 'translation': {'en': 'Wash that smelly head of yours, and wake up to your senses.', 'sk': 'Umyte si páchnucu hlavu, a prebuďte svoje zmysly.'}}
# {'id': '122', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [128], 'sk': [124]}}, 'translation': {'en': "You see me as a penniless girl who's trying to seduce a rich man, don't you?", 'sk': 'Vidíte ma ako chudobné dievča, ktoré sa snaží zviesť bohatého muža?'}}
# {'id': '123', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [129], 'sk': [125]}}, 'translation': {'en': "I'm still going to do it.", 'sk': 'Stále po tom túžim.'}}
# {'id': '124', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [130], 'sk': [126]}}, 'translation': {'en': "Can't I just be your Candy?", 'sk': 'Nemôžem byť vaša Candy?'}}
# {'id': '125', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [131], 'sk': [127]}}, 'translation': {'en': 'Just because you try... do you think that you can seduce me?', 'sk': 'Myslíte si, že tým, že sa tak veľmi snažíte, ma dokážete zviesť?'}}
# {'id': '126', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [132], 'sk': [128]}}, 'translation': {'en': "Fine, why don't you try your best to lure me with your ghost friends?", 'sk': 'Fajn, prečo sa ma neskúsite nalákať pomocou svojich kamarátov duchov?'}}
# {'id': '127', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [133], 'sk': [129]}}, 'translation': {'en': 'You perverted Candy girl with your dirty hair.', 'sk': 'Vy perverzné Candy dievča so špinavými vlasmi.'}}
# {'id': '128', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [134], 'sk': [130]}}, 'translation': {'en': "It's Ms. Tae.", 'sk': 'Som Tae Yang. (Tae Yang=slnko)'}}
# {'id': '129', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [135], 'sk': [131]}}, 'translation': {'en': 'Tae Gong Shil.', 'sk': 'Tae Gong Sil.'}}
# {'id': '130', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [136], 'sk': [132]}}, 'translation': {'en': "My name is Ms. Tae. (Ms. Tae translated as 'The Sun'.)", 'sk': 'Som slnko.'}}
# {'id': '131', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [137], 'sk': [133]}}, 'translation': {'en': 'Ms. Tae?', 'sk': 'Slnko?'}}
# {'id': '132', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [138], 'sk': [134]}}, 'translation': {'en': "If you're the sun... then I never want to see the morning again.", 'sk': 'Ak ste slnko... potom nikdy viac nechcem vidieť ráno.'}}
# {'id': '133', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [139], 'sk': [135]}}, 'translation': {'en': "The sun is going to rise, and I'm going to come to stay by your side.", 'sk': 'Slnko bude stúpať, a ja chcem byť s vami.'}}
# {'id': '134', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [140], 'sk': [136]}}, 'translation': {'en': "I'll make sure to wash my hair the next time I see you!", 'sk': 'Keď sa s vami nabudúce stretnem, budem mať umyté vlasy!'}}
# {'id': '135', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [141], 'sk': [137]}}, 'translation': {'en': "Mr. Joo. (Mr. Joo translated as 'The Master'.)", 'sk': 'Pán Joo.'}}
# {'id': '136', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [142], 'sk': [138]}}, 'translation': {'en': 'Did you get to see Ms. Tae?', 'sk': 'Bol ste za slečnou Tae?'}}
# {'id': '137', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [143], 'sk': [139]}}, 'translation': {'en': 'I meant, did you see Ms. Tae Gong Shil?', 'sk': 'Chcel som povedať, bol ste za slečnou Tae Gong Sil?'}}
# {'id': '138', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [144], 'sk': [140]}}, 'translation': {'en': "I never should've came here.", 'sk': 'Nikdy som sem nemal chodiť.'}}
# {'id': '139', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [145], 'sk': [141]}}, 'translation': {'en': "Let's go.", 'sk': 'Poďme.'}}
# {'id': '140', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [146], 'sk': [142]}}, 'translation': {'en': 'What was he doing here?', 'sk': 'Čo tu robil?'}}
# {'id': '141', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [147], 'sk': [143]}}, 'translation': {'en': "He probably thinks that I'm crazy.", 'sk': 'Zrejme si myslí, že som blázon.'}}
# {'id': '142', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [148], 'sk': [144]}}, 'translation': {'en': 'But I really can see them.', 'sk': 'Ale ja ich naozaj vidím.'}}
# {'id': '143', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [149], 'sk': [145]}}, 'translation': {'en': 'Hee Joo?', 'sk': 'Hee Joo?'}}
# {'id': '144', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [150], 'sk': [146]}}, 'translation': {'en': 'I really did see her, too.', 'sk': 'Aj ju som videla.'}}
# {'id': '145', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [151], 'sk': [147]}}, 'translation': {'en': 'There.', 'sk': 'Tam.'}}
# {'id': '146', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [152], 'sk': [148]}}, 'translation': {'en': "There's one right there.", 'sk': 'Teraz tu jeden je.'}}
# {'id': '147', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [153, 154], 'sk': [149]}}, 'translation': {'en': 'If such things as ghosts really does exist... I wish I could conjure her up just once.', 'sk': 'Ak duchovia naozaj existujú, chcel by som ju aspoň raz vykúzliť.'}}
# {'id': '148', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [155], 'sk': [150]}}, 'translation': {'en': 'Cha Hee Joo.', 'sk': 'Cha Hee Joo.'}}
# {'id': '149', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [156], 'sk': [151]}}, 'translation': {'en': 'Spirit, spirit...', 'sk': 'Duch, duch...'}}
# {'id': '150', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [157], 'sk': [152]}}, 'translation': {'en': 'Come to us.', 'sk': 'Príď k nám.'}}
# {'id': '151', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [158], 'sk': [153]}}, 'translation': {'en': 'Spirit, spirit...', 'sk': 'Duch, duch...'}}
# {'id': '152', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [159], 'sk': [154]}}, 'translation': {'en': 'Come to us.', 'sk': 'Príď k nám.'}}
# {'id': '153', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [160], 'sk': [155]}}, 'translation': {'en': 'Spirit, spirit...', 'sk': 'Duch, duch...'}}
# {'id': '154', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [161], 'sk': [156]}}, 'translation': {'en': 'Come to us.', 'sk': 'Príď k nám.'}}
# {'id': '155', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [162], 'sk': [157]}}, 'translation': {'en': 'Spirit, spirit...', 'sk': 'Duch, duch...'}}
# {'id': '156', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [163], 'sk': [158]}}, 'translation': {'en': 'Come to us.', 'sk': 'Príď k nám.'}}
# {'id': '157', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [164], 'sk': [159]}}, 'translation': {'en': 'What are they doing?', 'sk': 'Čo to robia?'}}
# {'id': '158', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [165], 'sk': [160]}}, 'translation': {'en': "They're calling Eun Seol's dead spirit.", 'sk': 'Vyvolávajú mŕtvu dušu Eun Seol.'}}
# {'id': '159', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [166], 'sk': [161]}}, 'translation': {'en': 'Spirit, spirit...', 'sk': 'Duch, duch...'}}
# {'id': '160', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [167], 'sk': [162]}}, 'translation': {'en': 'Are you here?', 'sk': 'Tu si?'}}
# {'id': '161', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [168], 'sk': [163]}}, 'translation': {'en': "She's here.", 'sk': 'Je tu.'}}
# {'id': '162', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [169], 'sk': [164]}}, 'translation': {'en': 'Are you...', 'sk': 'Si...'}}
# {'id': '163', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [170], 'sk': [165]}}, 'translation': {'en': 'Lee Eun Seol?', 'sk': 'Lee Eun Seol?'}}
# {'id': '164', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [171], 'sk': [166]}}, 'translation': {'en': "It says it's Eun Seol.", 'sk': 'Hovorí, že je Eun Seol.'}}
# {'id': '165', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [172], 'sk': [167]}}, 'translation': {'en': "They're just joking around.", 'sk': 'Robia si len srandu.'}}
# {'id': '166', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [173], 'sk': [168]}}, 'translation': {'en': "Don't pay them any attention.", 'sk': 'Nevenujte im žiadnu pozornosť.'}}
# {'id': '167', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [174], 'sk': [169]}}, 'translation': {'en': 'Why did you die?', 'sk': 'Prečo si zomrela?'}}
# {'id': '168', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [175], 'sk': [170]}}, 'translation': {'en': 'Is the person responsible for your death... in this room right now?', 'sk': 'Človek zodpovedný za tvoju smrť, je teraz v tejto miestnosti?'}}
# {'id': '169', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [176], 'sk': [171]}}, 'translation': {'en': 'Tell us.', 'sk': 'Povedz nám.'}}
# {'id': '170', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [177], 'sk': [172]}}, 'translation': {'en': 'Is she... here?', 'sk': 'Ona je... tu?'}}
# {'id': '171', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [178], 'sk': [173]}}, 'translation': {'en': 'We asked if the person responsible for your death is in this room right now.', 'sk': 'Pýtame sa, či osoba zodpovedná za tvoju smrť, je teraz v tejto miestnosti.'}}
# {'id': '172', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [179], 'sk': [174]}}, 'translation': {'en': 'What are you girls doing?', 'sk': 'Dievčatá, čo to robíte?'}}
# {'id': '173', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [180], 'sk': [175]}}, 'translation': {'en': 'Get back in your seats.', 'sk': 'Vráťte sa na svoje miesta.'}}
# {'id': '174', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [181], 'sk': [176]}}, 'translation': {'en': 'Do you think that Eun Seol was really here?', 'sk': 'Myslíš si, že Eun Seol tu naozaj bola?'}}
# {'id': '175', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [182], 'sk': [177]}}, 'translation': {'en': "Don't respond to a prank like that.", 'sk': 'Nereaguj na také hlúpe vtipy.'}}
# {'id': '176', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [183], 'sk': [178]}}, 'translation': {'en': "Let's just study.", 'sk': 'Poďme sa učiť.'}}
# {'id': '177', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [184], 'sk': [179]}}, 'translation': {'en': '[Lee Eun Seol]', 'sk': '[Lee Eun Seol]'}}
# {'id': '178', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [185], 'sk': [180]}}, 'translation': {'en': "- It's Eun Seol.", 'sk': '- To je Eun Seol.'}}
# {'id': '179', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [186], 'sk': [181]}}, 'translation': {'en': '- What?', 'sk': '- Čo?'}}
# {'id': '180', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [187], 'sk': [182]}}, 'translation': {'en': "Was this picture taken in front of our Kingdom Enterprise's fountain?", 'sk': 'Táto snímka bola vyhotovená pred našou fontánou v Kingdom Enterprises?'}}
# {'id': '181', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [188], 'sk': [183]}}, 'translation': {'en': 'Yes.', 'sk': 'Áno.'}}
# {'id': '182', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [189], 'sk': [184]}}, 'translation': {'en': 'This picture is all over the internet right now.', 'sk': 'Táto fotgrafia sa práve šíri po celom internete.'}}
# {'id': '183', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [190], 'sk': [185]}}, 'translation': {'en': "Are you sure this isn't some kind of a mistake?", 'sk': 'Ste si istá, že nejde o nejaký omyl?'}}
# {'id': '184', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [191], 'sk': [186]}}, 'translation': {'en': "You know how sometimes there's a glare in the picture if the camera isn't focused?", 'sk': 'Viete, ako keď sa niekedy na fotke objaví žiara, ak nie je zaostrená?'}}
# {'id': '185', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [192], 'sk': [187]}}, 'translation': {'en': 'But look at how all the other girls in the picture came out clearly.', 'sk': 'Ale pozrite sa, všetky ostatné dievčatá vyšli na fotografii veľmi jasne.'}}
# {'id': '186', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [193], 'sk': [188]}}, 'translation': {'en': "And don't you think that the position that the girl is standing is strange?", 'sk': 'A nemyslíte, že pozícia toho dievčaťa je divná?'}}
# {'id': '187', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [194], 'sk': [189]}}, 'translation': {'en': 'Look closely.', 'sk': 'Pozrite sa pozorne.'}}
# {'id': '188', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [195], 'sk': [190]}}, 'translation': {'en': 'It means that she was standing right here when this picture was taken.', 'sk': 'To znamená, že stála priamo tu, keď tú fotku urobili.'}}
# {'id': '189', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [196], 'sk': [191]}}, 'translation': {'en': 'Yes, I see.', 'sk': 'Áno, rozumiem.'}}
# {'id': '190', 'meta': {'year': 0, 'imdbId': 3245996, 'subtitleId': {'en': 5698460, 'sk': 5232687}, 'sentenceIds': {'en': [197], 'sk': [192]}}, 'translation': {'en': 'I doubt that she went into the water to get in the picture.', 'sk': 'Pochybujem, že išla do vody, aby sa dostala do záberu.'}}
# ...
# {'id': '22141', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [268], 'sk': [274]}}, 'translation': {'en': '- Turn right in here, driver.', 'sk': '- Obráťte sa priamo tam, kočiš.'}}
# {'id': '22142', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [269], 'sk': [275]}}, 'translation': {'en': '- Adiós, señor.', 'sk': '- Adiós, pane.'}}
# {'id': '22143', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [270], 'sk': [276]}}, 'translation': {'en': 'Adiós.', 'sk': 'Adiós.'}}
# {'id': '22144', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [271], 'sk': [277]}}, 'translation': {'en': '- Oh, Mother.', 'sk': '- Oh, matka.'}}
# {'id': '22145', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [272], 'sk': [278]}}, 'translation': {'en': '- Diego!', 'sk': '- Diego!'}}
# {'id': '22146', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [273], 'sk': [279]}}, 'translation': {'en': 'My son.', 'sk': 'Môj syn.'}}
# {'id': '22147', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [274], 'sk': [280]}}, 'translation': {'en': 'My baby.', 'sk': 'Moje dieťa.'}}
# {'id': '22148', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [275], 'sk': [281]}}, 'translation': {'en': 'Mother.', 'sk': 'Matka.'}}
# {'id': '22149', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [276], 'sk': [282]}}, 'translation': {'en': '- Hello, María.', 'sk': '- Ahoj, Maria.'}}
# {'id': '22150', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [277], 'sk': [283]}}, 'translation': {'en': "- I'm so happy to see you.", 'sk': '- Som šťastná, že Vás vidím.'}}
# {'id': '22151', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [278], 'sk': [284]}}, 'translation': {'en': 'Good old Juan, fat as ever.', 'sk': 'Dobrý starý Juan, silný ako nikdy.'}}
# {'id': '22152', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [279], 'sk': [285]}}, 'translation': {'en': 'Hello, Manuel.', 'sk': 'Ahoj, Manuel.'}}
# {'id': '22153', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [280], 'sk': [286]}}, 'translation': {'en': 'And José.', 'sk': 'I José.'}}
# {'id': '22154', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [281], 'sk': [287]}}, 'translation': {'en': "Where's Father?", 'sk': 'Kde je otec?'}}
# {'id': '22155', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [282], 'sk': [288]}}, 'translation': {'en': 'In the study with Fray Felipe.', 'sk': 'V pracovni s frátrom Felipe.'}}
# {'id': '22156', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [283], 'sk': [289]}}, 'translation': {'en': "Come, he's longing to see you.", 'sk': 'Poď, on ťa túži vidieť.'}}
# {'id': '22157', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [284], 'sk': [290]}}, 'translation': {'en': "- Take Don Diego's things to his room.", 'sk': '- Odneste veci Dona Diega do jeho izby.'}}
# {'id': '22158', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [285], 'sk': [291]}}, 'translation': {'en': '- Sí, señora.', 'sk': '- Áno, pani.'}}
# {'id': '22159', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [286], 'sk': [292]}}, 'translation': {'en': 'I tell you, these conditions are beyond bearing.', 'sk': 'Poviem ti, podmienky tu sú nezensiteľné.'}}
# {'id': '22160', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [287], 'sk': [293]}}, 'translation': {'en': 'This whole district, from the hills of Verdugo to the shores of Del Rey, is a stench in the nostrils of heaven.', 'sk': 'Celá táto krajina, od kopca Verdugo po pobrežie Del Rey, srdí neznesiteľne.'}}
# {'id': '22161', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [288], 'sk': [294]}}, 'translation': {'en': '- I know, I know.', 'sk': '- Viem, viem.'}}
# {'id': '22162', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [289], 'sk': [295]}}, 'translation': {'en': '- You know, yes, but what do you do about it?', 'sk': '- Vieš, ale čo robíš proti tomu?'}}
# {'id': '22163', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [290], 'sk': [296]}}, 'translation': {'en': '- Nothing.', 'sk': '- Nič.'}}
# {'id': '22164', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [291], 'sk': [297]}}, 'translation': {'en': '- What can...?', 'sk': '- Čo môžem...?'}}
# {'id': '22165', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [292], 'sk': [298]}}, 'translation': {'en': 'Diego!', 'sk': 'Diego!'}}
# {'id': '22166', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [293], 'sk': [299]}}, 'translation': {'en': '- Father.', 'sk': '- Ah, otče.'}}
# {'id': '22167', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [294], 'sk': [300]}}, 'translation': {'en': '- Diego.', 'sk': '- Diego.'}}
# {'id': '22168', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [295], 'sk': [301]}}, 'translation': {'en': 'My boy.', 'sk': 'Moje dieťa.'}}
# {'id': '22169', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [296], 'sk': [302]}}, 'translation': {'en': 'Padre.', 'sk': 'Padre.'}}
# {'id': '22170', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [297], 'sk': [303]}}, 'translation': {'en': 'Welcome back to your home and my heart, Diego.', 'sk': 'Vitaj doma a v mojom srdci, Diego.'}}
# {'id': '22171', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [298], 'sk': [304]}}, 'translation': {'en': "- Oh, Padre, I've missed your wise counsel.", 'sk': '- Oh, padre, chýbali mi Vaše múdre rady.'}}
# {'id': '22172', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [299], 'sk': [305]}}, 'translation': {'en': '- Not too greatly, I suspect.', 'sk': '- Nie veľmi, predpokladám.'}}
# {'id': '22173', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [300], 'sk': [306]}}, 'translation': {'en': 'You remember Don Miguel and Don José?', 'sk': 'Pamätáš si Dona Miguela i Dona José?'}}
# {'id': '22174', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [301], 'sk': [307]}}, 'translation': {'en': '- Señores.', 'sk': '- Páni.'}}
# {'id': '22175', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [302], 'sk': [308]}}, 'translation': {'en': '- Have you returned to steal more melons?', 'sk': '- Vrátil si sa kradnúť melóny?'}}
# {'id': '22176', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [303], 'sk': [309]}}, 'translation': {'en': 'Melons?', 'sk': 'Melóny?'}}
# {'id': '22177', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [304], 'sk': [310]}}, 'translation': {'en': 'This scamp and my scapegrace son crept into my garden and gorged themselves on my seed melons one year.', 'sk': 'Tento darebák a môj nezbedný syn sa v mojej záhrade cpali melónmi.'}}
# {'id': '22178', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [305], 'sk': [311]}}, 'translation': {'en': 'Oh, but God punished us, Don Miguel.', 'sk': 'Oh, ale boh nás potrestal, Don Miguel.'}}
# {'id': '22179', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [306], 'sk': [312]}}, 'translation': {'en': 'We were visited by the father of all bellyaches.', 'sk': 'Navštívil nás otec brušných problémov.'}}
# {'id': '22180', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [307], 'sk': [313]}}, 'translation': {'en': "But he's ripe for more than boyish pranks now, Alejandro.", 'sk': 'Ale on už vyrástol z detských žartov, Alejandro.'}}
# {'id': '22181', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [308], 'sk': [314]}}, 'translation': {'en': '- I feel good muscle here.', 'sk': '- Cítim tu dobré svaly.'}}
# {'id': '22182', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [309], 'sk': [315]}}, 'translation': {'en': '- Arms, muscle.', 'sk': '- Ruky, svaly.'}}
# {'id': '22183', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [310], 'sk': [316]}}, 'translation': {'en': 'You men!', 'sk': 'Títo chlapi!'}}
# {'id': '22184', 'meta': {'year': 1940, 'imdbId': 32762, 'subtitleId': {'en': 5909341, 'sk': 5556216}, 'sentenceIds': {'en': [311], 'sk': [317]}}, 'translation': {'en': 'Madre de Dios, is he without a face?', 'sk': 'Matka božia, je bez tváre?'}}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18416/3981016380.py in <module>
# ----> 1 dataset.map(f)
#
# ~\miniconda3\envs\master\lib\site-packages\datasets\dataset_dict.py in map(self, function, with_indices, input_columns, batched, batch_size, remove_columns, keep_in_memory, load_from_cache_file, cache_file_names, writer_batch_size, features, disable_nullable, fn_kwargs, num_proc, desc)
#     482             cache_file_names = {k: None for k in self}
#     483         return DatasetDict(
# --> 484             {
#     485                 k: dataset.map(
#     486                     function=function,
#
# ~\miniconda3\envs\master\lib\site-packages\datasets\dataset_dict.py in <dictcomp>(.0)
#     483         return DatasetDict(
#     484             {
# --> 485                 k: dataset.map(
#     486                     function=function,
#     487                     with_indices=with_indices,
#
# ~\miniconda3\envs\master\lib\site-packages\datasets\arrow_dataset.py in map(self, function, with_indices, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, load_from_cache_file, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, num_proc, suffix_template, new_fingerprint, desc)
#    2034
#    2035         if num_proc is None or num_proc == 1:
# -> 2036             return self._map_single(
#    2037                 function=function,
#    2038                 with_indices=with_indices,
#
# ~\miniconda3\envs\master\lib\site-packages\datasets\arrow_dataset.py in wrapper(*args, **kwargs)
#     501             self: "Dataset" = kwargs.pop("self")
#     502         # apply actual function
# --> 503         out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     504         datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     505         for dataset in datasets:
#
# ~\miniconda3\envs\master\lib\site-packages\datasets\arrow_dataset.py in wrapper(*args, **kwargs)
#     468         }
#     469         # apply actual function
# --> 470         out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     471         datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     472         # re-apply format to the output
#
# ~\miniconda3\envs\master\lib\site-packages\datasets\fingerprint.py in wrapper(*args, **kwargs)
#     404             # Call actual function
#     405
# --> 406             out = func(self, *args, **kwargs)
#     407
#     408             # Update fingerprint of in-place transforms + update in-place history of transforms
#
# ~\miniconda3\envs\master\lib\site-packages\datasets\arrow_dataset.py in _map_single(self, function, with_indices, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, load_from_cache_file, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, new_fingerprint, rank, offset, disable_tqdm, desc, cache_only)
#    2380                 )
#    2381                 if not batched:
# -> 2382                     for i, example in enumerate(pbar):
#    2383                         example = apply_function_on_filtered_inputs(example, i, offset=offset)
#    2384                         if update_data:
#
# ~\miniconda3\envs\master\lib\site-packages\tqdm\notebook.py in __iter__(self)
#     255     def __iter__(self):
#     256         try:
# --> 257             for obj in super(tqdm_notebook, self).__iter__():
#     258                 # return super(tqdm...) will not catch exception
#     259                 yield obj
#
# ~\miniconda3\envs\master\lib\site-packages\tqdm\std.py in __iter__(self)
#    1178
#    1179         try:
# -> 1180             for obj in iterable:
#    1181                 yield obj
#    1182                 # Update and possibly print the progressbar.
#
# ~\miniconda3\envs\master\lib\site-packages\datasets\arrow_dataset.py in __iter__(self)
#    1605         """
#    1606         for index in range(self.num_rows):
# -> 1607             yield self._getitem(
#    1608                 index,
#    1609                 decoded=False,
#
# ~\miniconda3\envs\master\lib\site-packages\datasets\arrow_dataset.py in _getitem(self, key, decoded, **kwargs)
#    1848         format_kwargs = format_kwargs if format_kwargs is not None else {}
#    1849         formatter = get_formatter(format_type, features=self.features, decoded=decoded, **format_kwargs)
# -> 1850         pa_subtable = query_table(self._data, key, indices=self._indices if self._indices is not None else None)
#    1851         formatted_output = format_table(
#    1852             pa_subtable, key, formatter=formatter, format_columns=format_columns, output_all_columns=output_all_columns
#
# ~\miniconda3\envs\master\lib\site-packages\datasets\formatting\formatting.py in query_table(table, key, indices)
#     452     # Query the main table
#     453     if indices is None:
# --> 454         pa_subtable = _query_table(table, key)
#     455     else:
#     456         pa_subtable = _query_table_with_indices_mapping(table, key, indices=indices)
#
# ~\miniconda3\envs\master\lib\site-packages\datasets\formatting\formatting.py in _query_table(table, key)
#      77     """
#      78     if isinstance(key, int):
# ---> 79         return table.fast_slice(key % table.num_rows, 1)
#      80     if isinstance(key, slice):
#      81         key = range(*key.indices(table.num_rows))
#
# ~\miniconda3\envs\master\lib\site-packages\datasets\table.py in fast_slice(self, offset, length)
#     136             batches[-1] = batches[-1].slice(0, offset + length - self._offsets[j])
#     137             batches[0] = batches[0].slice(offset - self._offsets[i])
# --> 138         return pa.Table.from_batches(batches, schema=self._schema)
#     139
#     140
#
# KeyboardInterrupt:
